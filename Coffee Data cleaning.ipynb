# %%
import pandas as pd

# %%
coffee_quality= pd.read_csv('merged_data_cleaned.csv')

# %%
coffee_quality.head()
# Out:
#    Unnamed: 0  Species                     Owner Country.of.Origin  \
# 0           0  Arabica                 metad plc          Ethiopia
# 1           1  Arabica                 metad plc          Ethiopia
# 2           2  Arabica  grounds for health admin         Guatemala
# 3           3  Arabica       yidnekachew dabessa          Ethiopia
# 4           4  Arabica                 metad plc          Ethiopia
#
#                                   Farm.Name Lot.Number       Mill ICO.Number  \
# 0                                 metad plc        NaN  metad plc  2014/2015
# 1                                 metad plc        NaN  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch        NaN        NaN        NaN
# 3     yidnekachew dabessa coffee plantation        NaN    wolensu        NaN
# 4                                 metad plc        NaN  metad plc  2014/2015
#
#                                  Company       Altitude  ...  Color  \
# ...

# %%
coffee_quality.shape
# Out:
# (1339, 44)

# %%
#remove NaN values
coffee_quality.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       7
# Country.of.Origin           1
# Farm.Name                 359
# Lot.Number               1063
# Mill                      318
# ICO.Number                157
# Company                   209
# Altitude                  226
# Region                     59
# Producer                  232
# Number.of.Bags              0
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               47
# Grading.Date                0
# Owner.1                     7
# Variety                   226
# Processing.Method         170
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %%
coffee_quality.shape
# Out:
# (132, 44)

# %%
coffee_quality.dropna(inplace=True)

# %%
#remove raws when the altitude is expressed in ft
coffee_quality[coffee_quality.unit_of_measurement !='ft']
# Out:
#       Unnamed: 0  Species                         Owner Country.of.Origin  \
# 29            29  Arabica        lin, che-hao krude 林哲豪            Taiwan
# 115          115  Arabica        lin, che-hao krude 林哲豪            Taiwan
# 125          125  Arabica  consejo salvadoreño del café       El Salvador
# 128          128  Arabica                  rodrigo soto        Costa Rica
# 129          129  Arabica     juan luis alvarado romero         Guatemala
# ...          ...      ...                           ...               ...
# 1235        1235  Arabica        lin, che-hao krude 林哲豪            Taiwan
# 1253        1253  Arabica               ipanema coffees            Brazil
# 1308        1308  Arabica    exportadora atlantic, s.a.         Nicaragua
# 1319        1319  Robusta                nishant gurjer             India
# 1322        1322  Robusta                nishant gurjer             India
#
#                               Farm.Name  \
# ...

# %%
#remove NaN columns
coffee_quality = coffee_quality.drop(['Lot.Number', 'Mill', 'ICO.Number', 'Certification.Address', 'Certification.Contact', 'Certification.Body', 'Quakers', 'Expiration'], axis=1)

# %%
coffee_quality.head()
# Out:
#      Unnamed: 0  Species                         Owner Country.of.Origin  \
# 29           29  Arabica        lin, che-hao krude 林哲豪            Taiwan
# 115         115  Arabica        lin, che-hao krude 林哲豪            Taiwan
# 125         125  Arabica  consejo salvadoreño del café       El Salvador
# 128         128  Arabica                  rodrigo soto        Costa Rica
# 129         129  Arabica     juan luis alvarado romero         Guatemala
#
#                     Farm.Name                                       Company  \
# 29   tsoustructive garden 鄒築園                      taiwan coffee laboratory
# 115         shi fang yuan 十方源                      taiwan coffee laboratory
# 125                 monterrey                       cafetalera del pacifico
# 128                 rio jorco                    panamerican coffee trading
# 129     san diego buena vista  waelti schoenfeld exportadores de cafe, s.a.
#
# ...

# %%
coffee_quality.to_csv('coffee_data_cleaned.csv')
